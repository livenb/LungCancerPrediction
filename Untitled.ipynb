# %%
# %matplotlib inline

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dicom
import os
import scipy.ndimage
import matplotlib.pyplot as plt

from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Some constants 
INPUT_FOLDER = 'data/sample_images/'
patients = os.listdir(INPUT_FOLDER)
patients.sort()
# Out:
# /home/livenb/anaconda2/lib/python2.7/site-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
# Load the scans in given folder path
def load_scan(path):
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: float(x.ImagePositionPatient[2]))
    try:
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    except:
        slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
        
    for s in slices:
        s.SliceThickness = slice_thickness
        
    return slices

# %%
patient1 = os.path.join(INPUT_FOLDER, patients[0])
os.listdir(patient1)
# Out:
# ['ab611e5865b1a4eb3d6c5f7d24bd4f4b.dcm',
#  'cd44c4938dc98489f512d6e1a827baf1.dcm',
#  '0678ae61b7c56dfaf35477f6d01a6ffc.dcm',
#  'ace7e133a0a9f34cd501b3108befa5a2.dcm',
#  'bcc85297b22ac2f948fb3bb7720366a2.dcm',
#  'f793659482982828da0cedb893757896.dcm',
#  '706594fd92bddfb2bf80db615b28bf16.dcm',
#  '9d44441b36c831a51ea2e70374b58965.dcm',
#  '27044e5a46b8135b4c031ac88aa8cf5f.dcm',
#  '6d795b5be1f7bb1046795e4a8598c342.dcm',
#  'ef6b0c74539af15d9ecfa7838b262492.dcm',
#  '80522596e3ca98563c3e1935056fb4fd.dcm',
#  '703c675b0898c2013f45be3beea6cd9b.dcm',
#  '83bad73cc432b79eaf8586d96f7569c6.dcm',
#  'edeb7615b9b172f104db566d11168409.dcm',
#  'b5759a0b02bada9b42d5e72fc7f7e2e1.dcm',
#  'd7379620d30f8c32835f2edca9751a4b.dcm',
#  '16486a1cd911b9108c52f2ac512380a5.dcm',
#  '35fcd8810898a36698ff815da15866e9.dcm',
#  'da1f5a82dafe221c8dfddfb578791240.dcm',
#  'e89d1e5a03f2eb6e265b0a8129b2818f.dcm',
#  '053a0460fb45227bd8e0e7b514a71e8e.dcm',
#  'b7acbc09401c3c3422e12a0d2bd3b060.dcm',
#  '0d546a5ae1473f772e6a8f271a049535.dcm',
#  'ac588b16cda110f04e5f83bb30820d43.dcm',
#  '0b8fdd1863b4362453001a94123ab40f.dcm',
#  'ed3738b5675409aa3f559c5dec35808a.dcm',
#  '08eb3a007acc90a45b6e1b92fb479adc.dcm',
#  '06ba0baeb0f26fb7aed5249eebbb77a9.dcm',
#  'ad68ddab98dfdd426756fd8772beccc0.dcm',
#  '521c54021dc54b7600e93ee1e78ca8cb.dcm',
#  'a1c4a5aebd5a5a05285caaef5223e960.dcm',
#  'ae318d30cde05384fddc4f208c981ee8.dcm',
#  '695978e4c5d229945731bac2d0e18105.dcm',
#  '5864eab592f8b5de9e8898825108bdce.dcm',
#  '0791f624c2f313bfe490ac940947977e.dcm',
#  'c6759a80d9b1cfc3d738cf9ae9d09cf0.dcm',
#  '0484f5a7f55eb7b6743cadaffcce586d.dcm',
#  'f21399d0c62ffe79318f72bb35135ded.dcm',
#  '2e56c90ec40b3ea7e4da9fb626609317.dcm',
#  '604a0b0f49d08af904d9d781a5214554.dcm',
#  'acb919b2f638288f0882292468e7a448.dcm',
#  '0ba4f3cf525a9da7e02e181957ca2bd8.dcm',
#  '3550f35f597290b97baa2650f93b791d.dcm',
#  '6c2809d0d8674e002200212cc87a9dcc.dcm',
#  '71ac828e20b7658e71f8bfc1dcb94520.dcm',
#  'ea8c85232f6cf79402df35bae75feffd.dcm',
#  '528c1786cee11ffcaedbf6fff50d461a.dcm',
#  '586dc3e4fac85947d6b5b0c343918a55.dcm',
#  'be2725ef51470b93ec87b2a7a5cd0271.dcm',
#  '48b6b98f614f1cd3f0c84c076131636a.dcm',
#  '995fa45fdcc074dee9a238bfa69f52b9.dcm',
#  '90c9eca7c554ea122560249fbf21f4e4.dcm',
#  '42804850e0b051df2cfa0b40c6c48016.dcm',
#  'f1c37407c78d2671e20522b3925a8755.dcm',
#  'fa7a21165ae152b13def786e6afc3edf.dcm',
#  '0cd80c17d64e56cc3b9f5d7229880a14.dcm',
#  '23df6bdd9ca404496cb5bb12ff1a4b1d.dcm',
#  'd9a736e6ccd36523622b555ab0de4ccc.dcm',
#  '3dff92c9581feafeb85d882b068b3158.dcm',
#  '6719877114f0856ddcba77d8d00c43cc.dcm',
#  'c4274a3b925a3ddcec7f4e46faece4cf.dcm',
#  'e14dd39443eafd70061fc6c4fa124be6.dcm',
#  '7665594ce7d0ddf325f7d6b4413dd411.dcm',
#  'e199e16def4488fbc6ea94dfd3c1a059.dcm',
#  '6daed9579a87f6e504c13e00b2eefa2c.dcm',
#  'c07458607a28441457df6485388d4893.dcm',
#  'da6760bd43d1fc0b10ceb82e35d2ceed.dcm',
#  'b792dbfc27d50dc33e1e0f4b47401a47.dcm',
#  '1d07f66753a81c3c6a4a1b3b55df860d.dcm',
#  '230964c7e9db96fef0b540380a5a72c4.dcm',
#  '31a692894ccb7d2b72ade72c007e74c8.dcm',
#  'c99fe81d18b0431a19872e8e4700849f.dcm',
#  'c621ac8da9de8f0c2f944e9ac9de3d92.dcm',
#  '7e84530c34d49e610c647015b5e956dd.dcm',
#  '233618b409b6f65cc26327d82fc773a6.dcm',
#  '3bfc063e5477d08cf8d613a188dd65e2.dcm']

# %%
s1 = dicom.read_file(os.path.join(patient1, 'ab611e5865b1a4eb3d6c5f7d24bd4f4b.dcm'))
s1
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.315996947592860262526161019511516624377
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0020) Patient ID                          LO: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.86208730140539712382771890501772734277950692397709007305473
# (0020, 000e) Series Instance UID                 UI: 2.25.11575877329635228925808596800269974740893519451784626046614
# (0020, 0011) Series Number                       IS: '3'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '77'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-145.500000', '-158.199997', '-213.699997']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.83033509634441686385652073462983801840121916678417719669650
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-213.699997'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.597656', '0.597656']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '400'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes

# %%
img = s1.pixel_array
fig, ax = plt.subplots()
cax = ax.imshow(img, cmap=plt.cm.gray)
fig.colorbar(cax)

# %%
plt.hist(img.flat, bins=100)
plt.show()

# %%
pd.value_counts(img.flat[img.flat < -1000])
# Out:
# -2000    55772
# dtype: int64

# %%
img[img == -2000] = 0
fig, ax = plt.subplots()
cax = ax.imshow(img, cmap=plt.cm.gray)
fig.colorbar(cax)
